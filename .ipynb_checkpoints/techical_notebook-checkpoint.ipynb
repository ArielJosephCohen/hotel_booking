# %% [markdown]
# ## GitHub: https://github.com/ArielJosephCohen/hotel_booking

# %% [markdown]
# ## Kaggle: https://www.kaggle.com/jessemostipak/hotel-booking-demand

# %% [markdown]
# # **Notebook**

# %%
seed = 14

# %%
# magic
# %matplotlib inline

# warnings
import warnings
warnings.filterwarnings(action='ignore')

# basic libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import math
from scipy import stats

# other libraries
import pydotplus
from numpy import loadtxt
from xgboost import XGBClassifier
from IPython.display import Image  
from imblearn.ensemble import BalancedRandomForestClassifier 
from imblearn.datasets import make_imbalance

# sci-kit learn libraries
from sklearn.metrics import confusion_matrix
from sklearn.metrics import f1_score
from sklearn.metrics import recall_score
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import roc_auc_score
from sklearn.metrics import auc
from sklearn.metrics import roc_curve
from sklearn.metrics import classification_report
from sklearn.feature_selection import rfe
from sklearn.feature_selection import RFECV
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import Perceptron
from sklearn.linear_model import SGDClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import export_graphviz
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC, LinearSVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.decomposition import PCA
from sklearn.utils import resample
from sklearn.externals.six import StringIO
# Out:
# Using TensorFlow backend.

# %%
df = pd.read_csv('hotel_bookings.csv')

# %%
print(df.shape)
df.head()
# Out:
# (119390, 32)
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# 1                        0                     0       2  ...    No Deposit
# 2                        0                     1       1  ...    No Deposit
# 3                        0                     1       1  ...    No Deposit
# 4                        0                     2       2  ...    No Deposit
#
#    agent company days_in_waiting_list customer_type   adr  \
# 0    NaN     NaN                    0     Transient   0.0
# 1    NaN     NaN                    0     Transient   0.0
# 2    NaN     NaN                    0     Transient  75.0
# 3  304.0     NaN                    0     Transient  75.0
# 4  240.0     NaN                    0     Transient  98.0
#
#    required_car_parking_spaces  total_of_special_requests  reservation_status  \
# 0                            0                          0           Check-Out
# 1                            0                          0           Check-Out
# 2                            0                          0           Check-Out
# 3                            0                          0           Check-Out
# 4                            0                          1           Check-Out
#
#   reservation_status_date
# 0              2015-07-01
# 1              2015-07-01
# 2              2015-07-02
# 3              2015-07-02
# 4              2015-07-03
#
# [5 rows x 32 columns]

# %%
df.drop('company',axis=1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 31 columns):
# hotel                             119390 non-null object
# is_canceled                       119390 non-null int64
# lead_time                         119390 non-null int64
# arrival_date_year                 119390 non-null int64
# arrival_date_month                119390 non-null object
# arrival_date_week_number          119390 non-null int64
# arrival_date_day_of_month         119390 non-null int64
# stays_in_weekend_nights           119390 non-null int64
# stays_in_week_nights              119390 non-null int64
# adults                            119390 non-null int64
# children                          119386 non-null float64
# babies                            119390 non-null int64
# meal                              119390 non-null object
# country                           118902 non-null object
# market_segment                    119390 non-null object
# distribution_channel              119390 non-null object
# is_repeated_guest                 119390 non-null int64
# previous_cancellations            119390 non-null int64
# previous_bookings_not_canceled    119390 non-null int64
# reserved_room_type                119390 non-null object
# assigned_room_type                119390 non-null object
# booking_changes                   119390 non-null int64
# deposit_type                      119390 non-null object
# agent                             103050 non-null float64
# days_in_waiting_list              119390 non-null int64
# customer_type                     119390 non-null object
# adr                               119390 non-null float64
# required_car_parking_spaces       119390 non-null int64
# total_of_special_requests         119390 non-null int64
# reservation_status                119390 non-null object
# reservation_status_date           119390 non-null object
# dtypes: float64(3), int64(16), object(12)
# memory usage: 28.2+ MB

# %%
df.agent.fillna((df.agent.mean()+df.agent.median())/2,inplace=True)

# %%
df.children.fillna((df.children.mean()+df.children.median())/2,inplace=True)

# %%
df.country.fillna('PRT',inplace=True)

# %%
print(df.shape)
df.head()
# Out:
# (119390, 31)
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  \
# 0                        0                     0       2  ...
# 1                        0                     0       2  ...
# 2                        0                     1       1  ...
# 3                        0                     1       1  ...
# 4                        0                     2       2  ...
#
#    booking_changes  deposit_type       agent days_in_waiting_list  \
# 0                3    No Deposit   50.346691                    0
# 1                4    No Deposit   50.346691                    0
# 2                0    No Deposit   50.346691                    0
# 3                0    No Deposit  304.000000                    0
# 4                0    No Deposit  240.000000                    0
#
#   customer_type   adr  required_car_parking_spaces  total_of_special_requests  \
# 0     Transient   0.0                            0                          0
# 1     Transient   0.0                            0                          0
# 2     Transient  75.0                            0                          0
# 3     Transient  75.0                            0                          0
# 4     Transient  98.0                            0                          1
#
#    reservation_status reservation_status_date
# 0           Check-Out              2015-07-01
# 1           Check-Out              2015-07-01
# 2           Check-Out              2015-07-02
# 3           Check-Out              2015-07-02
# 4           Check-Out              2015-07-03
#
# [5 rows x 31 columns]

# %%
for col in df.columns:
    if len(df[col].value_counts())==2:
        print(col,':',df[col].value_counts())
# Out:
# hotel : City Hotel      79330
# Resort Hotel    40060
# Name: hotel, dtype: int64
# is_canceled : 0    75166
# 1    44224
# Name: is_canceled, dtype: int64
# is_repeated_guest : 0    115580
# 1      3810
# Name: is_repeated_guest, dtype: int64

# %%
hotel_dict = {'City Hotel':1,'Resort Hotel':0}

# %%
df.hotel = df.hotel.map(lambda x: hotel_dict[x])

# %%
df.head()
# Out:
#    hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0      0            0        342               2015               July
# 1      0            0        737               2015               July
# 2      0            0          7               2015               July
# 3      0            0         13               2015               July
# 4      0            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  \
# 0                        0                     0       2  ...
# 1                        0                     0       2  ...
# 2                        0                     1       1  ...
# 3                        0                     1       1  ...
# 4                        0                     2       2  ...
#
#    booking_changes  deposit_type       agent days_in_waiting_list  \
# 0                3    No Deposit   50.346691                    0
# 1                4    No Deposit   50.346691                    0
# 2                0    No Deposit   50.346691                    0
# 3                0    No Deposit  304.000000                    0
# 4                0    No Deposit  240.000000                    0
#
#   customer_type   adr  required_car_parking_spaces  total_of_special_requests  \
# 0     Transient   0.0                            0                          0
# 1     Transient   0.0                            0                          0
# 2     Transient  75.0                            0                          0
# 3     Transient  75.0                            0                          0
# 4     Transient  98.0                            0                          1
#
#    reservation_status reservation_status_date
# 0           Check-Out              2015-07-01
# 1           Check-Out              2015-07-01
# 2           Check-Out              2015-07-02
# 3           Check-Out              2015-07-02
# 4           Check-Out              2015-07-03
#
# [5 rows x 31 columns]

# %%
df.deposit_type.value_counts()
# Out:
# No Deposit    104641
# Non Refund     14587
# Refundable       162
# Name: deposit_type, dtype: int64

# %%
(df[['deposit_type','is_canceled']].groupby(['deposit_type'], 
    as_index = False).mean().sort_values(by = 'is_canceled', ascending = False)).iloc[:,0]
(df[['deposit_type','is_canceled']].groupby(['deposit_type'], 
    as_index = False).mean().sort_values(by = 'is_canceled', ascending = False)).iloc[:,1]
# Out:
# 1    0.993624
# 0    0.283770
# 2    0.222222
# Name: is_canceled, dtype: float64

# %%
deposit_dict = {}
for i in range (0,3):
    deposit_dict[(df[['deposit_type','is_canceled']].groupby(['deposit_type'], 
    as_index = False).mean().sort_values(by = 'is_canceled', ascending = False)).iloc[:,0][i]]=1-(df[['deposit_type','is_canceled']].groupby(['deposit_type'], 
    as_index = False).mean().sort_values(by = 'is_canceled', ascending = False)).iloc[:,1][i]

# %%
deposit_dict
# Out:
# {'No Deposit': 0.7162297760915893,
#  'Non Refund': 0.006375539864262647,
#  'Refundable': 0.7777777777777778}

# %%
df.deposit_type = df.deposit_type.map(lambda x: deposit_dict[x])

# %%
month_dict = {'January':1,'February':2,'March':3,'April':4,'May':5,'June':6,'July':7,'August':8,'September':9,
             'October':10,'November':11,'December':12}

# %%
df.arrival_date_month=df.arrival_date_month.map(lambda x: month_dict[x])

# %%
print(df.shape)
df.head()
# Out:
# (119390, 31)
#    hotel  is_canceled  lead_time  arrival_date_year  arrival_date_month  \
# 0      0            0        342               2015                   7
# 1      0            0        737               2015                   7
# 2      0            0          7               2015                   7
# 3      0            0         13               2015                   7
# 4      0            0         14               2015                   7
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  \
# 0                        0                     0       2  ...
# 1                        0                     0       2  ...
# 2                        0                     1       1  ...
# 3                        0                     1       1  ...
# 4                        0                     2       2  ...
#
#    booking_changes  deposit_type       agent days_in_waiting_list  \
# 0                3       0.71623   50.346691                    0
# 1                4       0.71623   50.346691                    0
# 2                0       0.71623   50.346691                    0
# 3                0       0.71623  304.000000                    0
# 4                0       0.71623  240.000000                    0
#
#   customer_type   adr  required_car_parking_spaces  total_of_special_requests  \
# 0     Transient   0.0                            0                          0
# 1     Transient   0.0                            0                          0
# 2     Transient  75.0                            0                          0
# 3     Transient  75.0                            0                          0
# 4     Transient  98.0                            0                          1
#
#    reservation_status reservation_status_date
# 0           Check-Out              2015-07-01
# 1           Check-Out              2015-07-01
# 2           Check-Out              2015-07-02
# 3           Check-Out              2015-07-02
# 4           Check-Out              2015-07-03
#
# [5 rows x 31 columns]

# %%
(df[['customer_type','is_canceled']].groupby(['customer_type'], 
    as_index = False).mean().sort_values(by = 'is_canceled', ascending = False)).iloc[:,0]
((df[['customer_type','is_canceled']].groupby(['customer_type'], 
    as_index = False).mean().sort_values(by = 'is_canceled', ascending = False)).iloc[:,1])
# Out:
# 2    0.407463
# 0    0.309617
# 3    0.254299
# 1    0.102253
# Name: is_canceled, dtype: float64

# %%
customer_dict = {}
for i in range (len(((df[['customer_type','is_canceled']].groupby(['customer_type'], 
    as_index = False).mean().sort_values(by = 'is_canceled', ascending = False)).iloc[:,1]))):
    customer_dict[(df[['customer_type','is_canceled']].groupby(['customer_type'], 
    as_index = False).mean().sort_values(by = 'is_canceled', ascending = False)).iloc[:,0][i]]=1-(df[['customer_type','is_canceled']].groupby(['customer_type'], 
    as_index = False).mean().sort_values(by = 'is_canceled', ascending = False)).iloc[:,1][i]

# %%
customer_dict
# Out:
# {'Contract': 0.6903827281648676,
#  'Group': 0.8977469670710572,
#  'Transient': 0.5925367971164899,
#  'Transient-Party': 0.7457013214456296}

# %%
df.customer_type = df.customer_type.map(lambda x: customer_dict[x])

# %%
print(df.shape)
df.head()
# Out:
# (119390, 31)
#    hotel  is_canceled  lead_time  arrival_date_year  arrival_date_month  \
# 0      0            0        342               2015                   7
# 1      0            0        737               2015                   7
# 2      0            0          7               2015                   7
# 3      0            0         13               2015                   7
# 4      0            0         14               2015                   7
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  \
# 0                        0                     0       2  ...
# 1                        0                     0       2  ...
# 2                        0                     1       1  ...
# 3                        0                     1       1  ...
# 4                        0                     2       2  ...
#
#    booking_changes  deposit_type       agent days_in_waiting_list  \
# 0                3       0.71623   50.346691                    0
# 1                4       0.71623   50.346691                    0
# 2                0       0.71623   50.346691                    0
# 3                0       0.71623  304.000000                    0
# 4                0       0.71623  240.000000                    0
#
#   customer_type   adr  required_car_parking_spaces  total_of_special_requests  \
# 0      0.592537   0.0                            0                          0
# 1      0.592537   0.0                            0                          0
# 2      0.592537  75.0                            0                          0
# 3      0.592537  75.0                            0                          0
# 4      0.592537  98.0                            0                          1
#
#    reservation_status reservation_status_date
# 0           Check-Out              2015-07-01
# 1           Check-Out              2015-07-01
# 2           Check-Out              2015-07-02
# 3           Check-Out              2015-07-02
# 4           Check-Out              2015-07-03
#
# [5 rows x 31 columns]

# %%
reservation_dict = {}
for i in range (len(((df[['reservation_status','is_canceled']].groupby(['reservation_status'], 
    as_index = False).mean().sort_values(by = 'is_canceled', ascending = False)).iloc[:,1]))):
    reservation_dict[(df[['reservation_status','is_canceled']].groupby(['reservation_status'], 
    as_index = False).mean().sort_values(by = 'is_canceled', ascending = False)).iloc[:,0][i]]=1-(df[['reservation_status','is_canceled']].groupby(['reservation_status'], 
    as_index = False).mean().sort_values(by = 'is_canceled', ascending = False)).iloc[:,1][i]

# %%
df.reservation_status=df.reservation_status.map(lambda x: reservation_dict[x])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 31 columns):
# hotel                             119390 non-null int64
# is_canceled                       119390 non-null int64
# lead_time                         119390 non-null int64
# arrival_date_year                 119390 non-null int64
# arrival_date_month                119390 non-null int64
# arrival_date_week_number          119390 non-null int64
# arrival_date_day_of_month         119390 non-null int64
# stays_in_weekend_nights           119390 non-null int64
# stays_in_week_nights              119390 non-null int64
# adults                            119390 non-null int64
# children                          119390 non-null float64
# babies                            119390 non-null int64
# meal                              119390 non-null object
# country                           119390 non-null object
# market_segment                    119390 non-null object
# distribution_channel              119390 non-null object
# is_repeated_guest                 119390 non-null int64
# previous_cancellations            119390 non-null int64
# previous_bookings_not_canceled    119390 non-null int64
# reserved_room_type                119390 non-null object
# assigned_room_type                119390 non-null object
# booking_changes                   119390 non-null int64
# deposit_type                      119390 non-null float64
# agent                             119390 non-null float64
# days_in_waiting_list              119390 non-null int64
# customer_type                     119390 non-null float64
# adr                               119390 non-null float64
# required_car_parking_spaces       119390 non-null int64
# total_of_special_requests         119390 non-null int64
# reservation_status                119390 non-null int64
# reservation_status_date           119390 non-null object
# dtypes: float64(5), int64(19), object(7)
# memory usage: 28.2+ MB

# %%
cat_list = ['meal','country','distribution_channel','reserved_room_type','assigned_room_type','market_segment','reservation_status_date']

# %%
df.got_correct_room = df.reserved_room_type==df.assigned_room_type

# %%
room_assign_dict = {False:0,True:1}

# %%
df.got_correct_room = df.got_correct_room.map(lambda x: room_assign_dict[x])

# %%
for col in cat_list:
    dummy_df = (df[[col,'is_canceled']].groupby([col], 
    as_index = False).mean().sort_values(by = 'is_canceled', ascending = False))
    dummy_dict = {}
    for i in range (len(((dummy_df[[col,'is_canceled']].groupby([col],as_index = False).mean().sort_values(by = 'is_canceled', ascending = False)).iloc[:,1]))):
        dummy_dict[(dummy_df[[col,'is_canceled']].groupby([col], 
        as_index = False).mean().sort_values(by = 'is_canceled', ascending = False)).iloc[:,0][i]]=1-(dummy_df[[col,'is_canceled']].groupby([col], 
        as_index = False).mean().sort_values(by = 'is_canceled', ascending = False)).iloc[:,1][i]
    df[col]=df[col].map(lambda x: dummy_dict[x])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 31 columns):
# hotel                             119390 non-null int64
# is_canceled                       119390 non-null int64
# lead_time                         119390 non-null int64
# arrival_date_year                 119390 non-null int64
# arrival_date_month                119390 non-null int64
# arrival_date_week_number          119390 non-null int64
# arrival_date_day_of_month         119390 non-null int64
# stays_in_weekend_nights           119390 non-null int64
# stays_in_week_nights              119390 non-null int64
# adults                            119390 non-null int64
# children                          119390 non-null float64
# babies                            119390 non-null int64
# meal                              119390 non-null float64
# country                           119390 non-null float64
# market_segment                    119390 non-null float64
# distribution_channel              119390 non-null float64
# is_repeated_guest                 119390 non-null int64
# previous_cancellations            119390 non-null int64
# previous_bookings_not_canceled    119390 non-null int64
# reserved_room_type                119390 non-null float64
# assigned_room_type                119390 non-null float64
# booking_changes                   119390 non-null int64
# deposit_type                      119390 non-null float64
# agent                             119390 non-null float64
# days_in_waiting_list              119390 non-null int64
# customer_type                     119390 non-null float64
# adr                               119390 non-null float64
# required_car_parking_spaces       119390 non-null int64
# total_of_special_requests         119390 non-null int64
# reservation_status                119390 non-null int64
# reservation_status_date           119390 non-null float64
# dtypes: float64(12), int64(19)
# memory usage: 28.2 MB

# %%
print(df.shape)
df.head()
# Out:
# (119390, 31)
#    hotel  is_canceled  lead_time  arrival_date_year  arrival_date_month  \
# 0      0            0        342               2015                   7
# 1      0            0        737               2015                   7
# 2      0            0          7               2015                   7
# 3      0            0         13               2015                   7
# 4      0            0         14               2015                   7
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  \
# 0                        0                     0       2  ...
# 1                        0                     0       2  ...
# 2                        0                     1       1  ...
# 3                        0                     1       1  ...
# 4                        0                     2       2  ...
#
#    booking_changes  deposit_type       agent  days_in_waiting_list  \
# 0                3       0.71623   50.346691                     0
# 1                4       0.71623   50.346691                     0
# 2                0       0.71623   50.346691                     0
# 3                0       0.71623  304.000000                     0
# 4                0       0.71623  240.000000                     0
#
#    customer_type   adr  required_car_parking_spaces  \
# 0       0.592537   0.0                            0
# 1       0.592537   0.0                            0
# 2       0.592537  75.0                            0
# 3       0.592537  75.0                            0
# 4       0.592537  98.0                            0
#
#    total_of_special_requests  reservation_status  reservation_status_date
# 0                          0                   1                 0.200000
# 1                          0                   1                 0.200000
# 2                          0                   1                 0.014925
# 3                          0                   1                 0.014925
# 4                          1                   1                 0.477124
#
# [5 rows x 31 columns]

# %%
plt.figure(figsize=(15,8))
plt.tight_layout()
sns.heatmap(abs((df.drop('is_canceled',axis=1)).corr())>=0.7,cmap="Paired")

# %%
df.drop(['assigned_room_type','arrival_date_month'],axis=1,inplace=True)

# %%
plt.figure(figsize=(15,8))
plt.tight_layout()
sns.heatmap(abs((df.drop('is_canceled',axis=1)).corr())>=0.7,cmap="Paired")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 29 columns):
# hotel                             119390 non-null int64
# is_canceled                       119390 non-null int64
# lead_time                         119390 non-null int64
# arrival_date_year                 119390 non-null int64
# arrival_date_week_number          119390 non-null int64
# arrival_date_day_of_month         119390 non-null int64
# stays_in_weekend_nights           119390 non-null int64
# stays_in_week_nights              119390 non-null int64
# adults                            119390 non-null int64
# children                          119390 non-null float64
# babies                            119390 non-null int64
# meal                              119390 non-null float64
# country                           119390 non-null float64
# market_segment                    119390 non-null float64
# distribution_channel              119390 non-null float64
# is_repeated_guest                 119390 non-null int64
# previous_cancellations            119390 non-null int64
# previous_bookings_not_canceled    119390 non-null int64
# reserved_room_type                119390 non-null float64
# booking_changes                   119390 non-null int64
# deposit_type                      119390 non-null float64
# agent                             119390 non-null float64
# days_in_waiting_list              119390 non-null int64
# customer_type                     119390 non-null float64
# adr                               119390 non-null float64
# required_car_parking_spaces       119390 non-null int64
# total_of_special_requests         119390 non-null int64
# reservation_status                119390 non-null int64
# reservation_status_date           119390 non-null float64
# dtypes: float64(11), int64(18)
# memory usage: 26.4 MB

# %%
X = df.drop('is_canceled',axis=1)
y = df.is_canceled

# %%
rfc = RandomForestClassifier(random_state=seed)
rfecv = RFECV(estimator=rfc, step=1, cv=StratifiedKFold(8), scoring='accuracy',min_features_to_select=15)
rfecv.fit(X, y)
# Out:
# RFECV(cv=StratifiedKFold(n_splits=8, random_state=None, shuffle=False),
#       estimator=RandomForestClassifier(bootstrap=True, ccp_alpha=0.0,
#                                        class_weight=None, criterion='gini',
#                                        max_depth=None, max_features='auto',
#                                        max_leaf_nodes=None, max_samples=None,
#                                        min_impurity_decrease=0.0,
#                                        min_impurity_split=None,
#                                        min_samples_leaf=1, min_samples_split=2,
#                                        min_weight_fraction_leaf=0.0,
#                                        n_estimators=100, n_jobs=None,
#                                        oob_score=False, random_state=14,
#                                        verbose=0, warm_start=False),
#       min_features_to_select=15, n_jobs=None, scoring='accuracy', step=1,
#       verbose=0)

# %%
support_list = list(rfecv.support_)

# %%
importance = []
for val, sup in list(zip(X.columns,support_list)):
    if sup == True:
        importance.append(val)

# %%
print(X[importance].shape)
X[importance].head()
# Out:
# (119390, 15)
#    lead_time  arrival_date_year   country  market_segment  \
# 0        342               2015  0.437915        0.846581
# 1        737               2015  0.437915        0.846581
# 2          7               2015  0.797757        0.846581
# 3         13               2015  0.797757        0.812653
# 4         14               2015  0.797757        0.632789
#
#    distribution_channel  previous_cancellations  booking_changes  \
# 0              0.825401                       0                3
# 1              0.825401                       0                4
# 2              0.825401                       0                0
# 3              0.779242                       0                0
# 4              0.589741                       0                0
#
#    deposit_type       agent  customer_type   adr  required_car_parking_spaces  \
# 0       0.71623   50.346691       0.592537   0.0                            0
# 1       0.71623   50.346691       0.592537   0.0                            0
# 2       0.71623   50.346691       0.592537  75.0                            0
# 3       0.71623  304.000000       0.592537  75.0                            0
# 4       0.71623  240.000000       0.592537  98.0                            0
#
#    total_of_special_requests  reservation_status  reservation_status_date
# 0                          0                   1                 0.200000
# 1                          0                   1                 0.200000
# 2                          0                   1                 0.014925
# 3                          0                   1                 0.014925
# 4                          1                   1                 0.477124

# %%
x_and_y = pd.concat([X[importance],y],axis=1)

# %%
x_and_y = x_and_y[(np.abs(stats.zscore(x_and_y)) <= 3).all(axis=1)]
print(x_and_y.shape)
x_and_y.head()
# Out:
# (104014, 16)
#    lead_time  arrival_date_year   country  market_segment  \
# 2          7               2015  0.797757        0.846581
# 3         13               2015  0.797757        0.812653
# 4         14               2015  0.797757        0.632789
# 5         14               2015  0.797757        0.632789
# 6          0               2015  0.437915        0.846581
#
#    distribution_channel  previous_cancellations  booking_changes  \
# 2              0.825401                       0                0
# 3              0.779242                       0                0
# 4              0.589741                       0                0
# 5              0.589741                       0                0
# 6              0.825401                       0                0
#
#    deposit_type       agent  customer_type    adr  \
# 2       0.71623   50.346691       0.592537   75.0
# 3       0.71623  304.000000       0.592537   75.0
# 4       0.71623  240.000000       0.592537   98.0
# 5       0.71623  240.000000       0.592537   98.0
# 6       0.71623   50.346691       0.592537  107.0
#
#    required_car_parking_spaces  total_of_special_requests  reservation_status  \
# 2                            0                          0                   1
# 3                            0                          0                   1
# 4                            0                          1                   1
# 5                            0                          1                   1
# 6                            0                          0                   1
#
#    reservation_status_date  is_canceled
# 2                 0.014925            0
# 3                 0.014925            0
# 4                 0.477124            0
# 5                 0.477124            0
# 6                 0.477124            0

# %%
X = x_and_y.drop('is_canceled',axis=1)
y = x_and_y.is_canceled

# %%
scaler = MinMaxScaler()
for col in X.columns:
    if (X[col]>=1).sum() > 0:
        X[col] = scaler.fit_transform(X[[col]])

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,random_state=seed,test_size=0.3)

# %%
y_train.value_counts()
# Out:
# 0    43901
# 1    28908
# Name: is_canceled, dtype: int64

# %%
X_train, y_train = make_imbalance(X_train, y_train, sampling_strategy = {0:28908,1:28908})

# %%
y_train.value_counts()
# Out:
# 1    28908
# 0    28908
# Name: is_canceled, dtype: int64

# %%
XGB = XGBClassifier(colsample_bytree=0.3, gamma=0.4, max_depth=9, min_child_weight=3, n_estimators=28)
XGB.fit(X_train, y_train)
Y_pred = XGB.predict(X_train)
acc_XGB = round(XGB.score(X_train, y_train) * 100, 2)
r_XGB = round(recall_score(y_train,Y_pred) * 100, 2)
p_XGB = round(precision_score(y_train,Y_pred) * 100, 2)
f_XGB = round(f1_score(y_train,Y_pred) * 100, 2)
print(f'accuracy: {acc_XGB},recall: {r_XGB}, precision: {p_XGB},f1: {f_XGB}')
print('')
fpr, tpr, threshold = roc_curve(y_train, Y_pred)
print(f'AUC: {round(auc(fpr,tpr),3)*100}')
print('')
plt.tight_layout()
plt.figure(figsize=(7,4))
(sns.heatmap(confusion_matrix(y_train, Y_pred),cmap="YlGnBu"))
# Out:
# accuracy: 99.12,recall: 98.57, precision: 99.66,f1: 99.11
#
# AUC: 99.1

# %%
XGB = XGBClassifier(colsample_bytree=0.3, gamma=0.4, max_depth=9, min_child_weight=3, n_estimators=28)
XGB.fit(X_train, y_train)
Y_pred = XGB.predict(X_test)
acc_XGB = round(XGB.score(X_test, y_test) * 100, 2)
r_XGB = round(recall_score(y_test,Y_pred) * 100, 2)
p_XGB = round(precision_score(y_test,Y_pred) * 100, 2)
f_XGB = round(f1_score(y_test,Y_pred) * 100, 2)
print(f'accuracy: {acc_XGB},recall: {r_XGB}, precision: {p_XGB},f1: {f_XGB}')
print('')
fpr, tpr, threshold = roc_curve(y_test, Y_pred)
print(f'AUC: {round(auc(fpr,tpr),3)*100}')
print('')
plt.tight_layout()
plt.figure(figsize=(7,4))
(sns.heatmap(confusion_matrix(y_test, Y_pred),cmap="YlGnBu"))
# Out:
# accuracy: 98.95,recall: 98.02, precision: 99.35,f1: 98.68
#
# AUC: 98.8

# %%
from xgboost import plot_importance
plt.tight_layout()
plt.figure(figsize=(15,8))
plot_importance(XGB)
plt.show()

# %%
rf = RandomForestClassifier()
rf.fit(X_train,y_train)
pred = rf.predict(X_test)
score = rf.score(X_test,y_test)

# %%
a = pd.DataFrame(rf.feature_importances_).T
a.columns = X.columns

# %%
importance_of_features = a.T.sort_values(by=0,ascending=False)
importance_of_features
# Out:
#                                     0
# reservation_status           0.745418
# reservation_status_date      0.072920
# deposit_type                 0.048578
# country                      0.033495
# lead_time                    0.029534
# market_segment               0.015630
# total_of_special_requests    0.011292
# previous_cancellations       0.011065
# customer_type                0.007993
# agent                        0.007930
# adr                          0.006189
# booking_changes              0.004026
# distribution_channel         0.003097
# arrival_date_year            0.002834
# required_car_parking_spaces  0.000000
