# %% [markdown]
# ## GitHub: https://github.com/ArielJosephCohen/hotel_booking

# %% [markdown]
# ## Kaggle: https://www.kaggle.com/jessemostipak/hotel-booking-demand

# %% [markdown]
# # **Notebook**

# %%
seed = 14

# %%
# magic
# %matplotlib inline

# warnings
import warnings
warnings.filterwarnings(action='ignore')

# basic libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import math
from scipy import stats

# other libraries
import pydotplus
from numpy import loadtxt
from xgboost import XGBClassifier
from IPython.display import Image  
from imblearn.ensemble import BalancedRandomForestClassifier 
from imblearn.datasets import make_imbalance

# sci-kit learn libraries
from sklearn.metrics import confusion_matrix
from sklearn.metrics import f1_score
from sklearn.metrics import recall_score
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import roc_auc_score
from sklearn.metrics import auc
from sklearn.metrics import roc_curve
from sklearn.metrics import classification_report
from sklearn.feature_selection import rfe
from sklearn.feature_selection import RFECV
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import Perceptron
from sklearn.linear_model import SGDClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import export_graphviz
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC, LinearSVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.decomposition import PCA
from sklearn.utils import resample
from sklearn.externals.six import StringIO
# Out:
# Using TensorFlow backend.

# %%
df = pd.read_csv('hotel_bookings.csv')

# %%
print(df.shape)
df.head()
# Out:
# (119390, 32)
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# ...

# %%
df.drop_duplicates(keep='first').shape
# Out:
# (87396, 32)

# %%
df = df.drop_duplicates(keep='first')

# %%
df.drop('company',axis=1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 87396 entries, 0 to 119389
# Data columns (total 31 columns):
# hotel                             87396 non-null object
# is_canceled                       87396 non-null int64
# lead_time                         87396 non-null int64
# arrival_date_year                 87396 non-null int64
# arrival_date_month                87396 non-null object
# arrival_date_week_number          87396 non-null int64
# arrival_date_day_of_month         87396 non-null int64
# stays_in_weekend_nights           87396 non-null int64
# stays_in_week_nights              87396 non-null int64
# adults                            87396 non-null int64
# children                          87392 non-null float64
# babies                            87396 non-null int64
# meal                              87396 non-null object
# country                           86944 non-null object
# market_segment                    87396 non-null object
# ...

# %%
df.agent.fillna((df.agent.mean()+df.agent.median())/2,inplace=True)

# %%
df.children.fillna((df.children.mean()+df.children.median())/2,inplace=True)

# %%
df.country.fillna('PRT',inplace=True)

# %%
print(df.shape)
df.head()
# Out:
# (87396, 31)
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  \
# 0                        0                     0       2  ...
# ...

# %%
for col in df.columns:
    if len(df[col].value_counts())==2:
        print(col,':',df[col].value_counts())
# Out:
# hotel : City Hotel      53428
# Resort Hotel    33968
# Name: hotel, dtype: int64
# is_canceled : 0    63371
# 1    24025
# Name: is_canceled, dtype: int64
# is_repeated_guest : 0    83981
# 1     3415
# Name: is_repeated_guest, dtype: int64

# %%
hotel_dict = {'City Hotel':1,'Resort Hotel':0}

# %%
df.hotel = df.hotel.map(lambda x: hotel_dict[x])

# %%
df.head()
# Out:
#    hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0      0            0        342               2015               July
# 1      0            0        737               2015               July
# 2      0            0          7               2015               July
# 3      0            0         13               2015               July
# 4      0            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  \
# 0                        0                     0       2  ...
# 1                        0                     0       2  ...
# ...

# %%
df.deposit_type.value_counts()
# Out:
# No Deposit    86251
# Non Refund     1038
# Refundable      107
# Name: deposit_type, dtype: int64

# %%
(df[['deposit_type','is_canceled']].groupby(['deposit_type'], 
    as_index = False).mean().sort_values(by = 'is_canceled', ascending = False)).iloc[:,0]
(df[['deposit_type','is_canceled']].groupby(['deposit_type'], 
    as_index = False).mean().sort_values(by = 'is_canceled', ascending = False)).iloc[:,1]
# Out:
# 1    0.947013
# 0    0.266849
# 2    0.242991
# Name: is_canceled, dtype: float64

# %%
deposit_dict = {}
for i in range (0,3):
    deposit_dict[(df[['deposit_type','is_canceled']].groupby(['deposit_type'], 
    as_index = False).mean().sort_values(by = 'is_canceled', ascending = False)).iloc[:,0][i]]=1-(df[['deposit_type','is_canceled']].groupby(['deposit_type'], 
    as_index = False).mean().sort_values(by = 'is_canceled', ascending = False)).iloc[:,1][i]

# %%
deposit_dict
# Out:
# {'No Deposit': 0.7331509199893335,
#  'Non Refund': 0.05298651252408482,
#  'Refundable': 0.7570093457943925}

# %%
df.deposit_type = df.deposit_type.map(lambda x: deposit_dict[x])

# %%
month_dict = {'January':1,'February':2,'March':3,'April':4,'May':5,'June':6,'July':7,'August':8,'September':9,
             'October':10,'November':11,'December':12}

# %%
df.arrival_date_month=df.arrival_date_month.map(lambda x: month_dict[x])

# %%
print(df.shape)
df.head()
# Out:
# (87396, 31)
#    hotel  is_canceled  lead_time  arrival_date_year  arrival_date_month  \
# 0      0            0        342               2015                   7
# 1      0            0        737               2015                   7
# 2      0            0          7               2015                   7
# 3      0            0         13               2015                   7
# 4      0            0         14               2015                   7
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  \
# 0                        0                     0       2  ...
# ...

# %%
(df[['customer_type','is_canceled']].groupby(['customer_type'], 
    as_index = False).mean().sort_values(by = 'is_canceled', ascending = False)).iloc[:,0]
((df[['customer_type','is_canceled']].groupby(['customer_type'], 
    as_index = False).mean().sort_values(by = 'is_canceled', ascending = False)).iloc[:,1])
# Out:
# 2    0.301059
# 0    0.163109
# 3    0.152383
# 1    0.099265
# Name: is_canceled, dtype: float64

# %%
customer_dict = {}
for i in range (len(((df[['customer_type','is_canceled']].groupby(['customer_type'], 
    as_index = False).mean().sort_values(by = 'is_canceled', ascending = False)).iloc[:,1]))):
    customer_dict[(df[['customer_type','is_canceled']].groupby(['customer_type'], 
    as_index = False).mean().sort_values(by = 'is_canceled', ascending = False)).iloc[:,0][i]]=1-(df[['customer_type','is_canceled']].groupby(['customer_type'], 
    as_index = False).mean().sort_values(by = 'is_canceled', ascending = False)).iloc[:,1][i]

# %%
customer_dict
# Out:
# {'Contract': 0.836890729531698,
#  'Group': 0.9007352941176471,
#  'Transient': 0.6989414608396076,
#  'Transient-Party': 0.8476166112390211}

# %%
df.customer_type = df.customer_type.map(lambda x: customer_dict[x])

# %%
print(df.shape)
df.head()
# Out:
# (87396, 31)
#    hotel  is_canceled  lead_time  arrival_date_year  arrival_date_month  \
# 0      0            0        342               2015                   7
# 1      0            0        737               2015                   7
# 2      0            0          7               2015                   7
# 3      0            0         13               2015                   7
# 4      0            0         14               2015                   7
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  \
# 0                        0                     0       2  ...
# ...

# %%
reservation_dict = {}
for i in range (len(((df[['reservation_status','is_canceled']].groupby(['reservation_status'], 
    as_index = False).mean().sort_values(by = 'is_canceled', ascending = False)).iloc[:,1]))):
    reservation_dict[(df[['reservation_status','is_canceled']].groupby(['reservation_status'], 
    as_index = False).mean().sort_values(by = 'is_canceled', ascending = False)).iloc[:,0][i]]=1-(df[['reservation_status','is_canceled']].groupby(['reservation_status'], 
    as_index = False).mean().sort_values(by = 'is_canceled', ascending = False)).iloc[:,1][i]

# %%
df.reservation_status=df.reservation_status.map(lambda x: reservation_dict[x])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 87396 entries, 0 to 119389
# Data columns (total 31 columns):
# hotel                             87396 non-null int64
# is_canceled                       87396 non-null int64
# lead_time                         87396 non-null int64
# arrival_date_year                 87396 non-null int64
# arrival_date_month                87396 non-null int64
# arrival_date_week_number          87396 non-null int64
# arrival_date_day_of_month         87396 non-null int64
# stays_in_weekend_nights           87396 non-null int64
# stays_in_week_nights              87396 non-null int64
# adults                            87396 non-null int64
# children                          87396 non-null float64
# babies                            87396 non-null int64
# meal                              87396 non-null object
# country                           87396 non-null object
# market_segment                    87396 non-null object
# ...

# %%
cat_list = ['meal','country','distribution_channel','reserved_room_type','assigned_room_type','market_segment','reservation_status_date']

# %%
df.got_correct_room = df.reserved_room_type==df.assigned_room_type

# %%
room_assign_dict = {False:0,True:1}

# %%
df.got_correct_room = df.got_correct_room.map(lambda x: room_assign_dict[x])

# %%
for col in cat_list:
    dummy_df = (df[[col,'is_canceled']].groupby([col], 
    as_index = False).mean().sort_values(by = 'is_canceled', ascending = False))
    dummy_dict = {}
    for i in range (len(((dummy_df[[col,'is_canceled']].groupby([col],as_index = False).mean().sort_values(by = 'is_canceled', ascending = False)).iloc[:,1]))):
        dummy_dict[(dummy_df[[col,'is_canceled']].groupby([col], 
        as_index = False).mean().sort_values(by = 'is_canceled', ascending = False)).iloc[:,0][i]]=1-(dummy_df[[col,'is_canceled']].groupby([col], 
        as_index = False).mean().sort_values(by = 'is_canceled', ascending = False)).iloc[:,1][i]
    df[col]=df[col].map(lambda x: dummy_dict[x])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 87396 entries, 0 to 119389
# Data columns (total 31 columns):
# hotel                             87396 non-null int64
# is_canceled                       87396 non-null int64
# lead_time                         87396 non-null int64
# arrival_date_year                 87396 non-null int64
# arrival_date_month                87396 non-null int64
# arrival_date_week_number          87396 non-null int64
# arrival_date_day_of_month         87396 non-null int64
# stays_in_weekend_nights           87396 non-null int64
# stays_in_week_nights              87396 non-null int64
# adults                            87396 non-null int64
# children                          87396 non-null float64
# babies                            87396 non-null int64
# meal                              87396 non-null float64
# country                           87396 non-null float64
# market_segment                    87396 non-null float64
# ...

# %%
print(df.shape)
df.head()
# Out:
# (87396, 31)
#    hotel  is_canceled  lead_time  arrival_date_year  arrival_date_month  \
# 0      0            0        342               2015                   7
# 1      0            0        737               2015                   7
# 2      0            0          7               2015                   7
# 3      0            0         13               2015                   7
# 4      0            0         14               2015                   7
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  \
# 0                        0                     0       2  ...
# ...

# %%
plt.figure(figsize=(15,8))
plt.tight_layout()
sns.heatmap(abs((df.drop('is_canceled',axis=1)).corr())>=0.7,cmap="Paired")

# %%
df.drop(['assigned_room_type','arrival_date_month'],axis=1,inplace=True)

# %%
plt.figure(figsize=(15,8))
plt.tight_layout()
sns.heatmap(abs((df.drop('is_canceled',axis=1)).corr())>=0.7,cmap="Paired")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 87396 entries, 0 to 119389
# Data columns (total 29 columns):
# hotel                             87396 non-null int64
# is_canceled                       87396 non-null int64
# lead_time                         87396 non-null int64
# arrival_date_year                 87396 non-null int64
# arrival_date_week_number          87396 non-null int64
# arrival_date_day_of_month         87396 non-null int64
# stays_in_weekend_nights           87396 non-null int64
# stays_in_week_nights              87396 non-null int64
# adults                            87396 non-null int64
# children                          87396 non-null float64
# babies                            87396 non-null int64
# meal                              87396 non-null float64
# country                           87396 non-null float64
# market_segment                    87396 non-null float64
# distribution_channel              87396 non-null float64
# ...

# %%
df['Target']=df.is_canceled
df.drop('is_canceled',axis=1,inplace=True)

# %%
X = df.drop('Target',axis=1)
y = df.Target

# %%
rfc = RandomForestClassifier(random_state=seed)
rfecv = RFECV(estimator=rfc, step=1, cv=StratifiedKFold(8), scoring='accuracy',min_features_to_select=15)
rfecv.fit(X, y)
# Out:
# RFECV(cv=StratifiedKFold(n_splits=8, random_state=None, shuffle=False),
#       estimator=RandomForestClassifier(bootstrap=True, ccp_alpha=0.0,
#                                        class_weight=None, criterion='gini',
#                                        max_depth=None, max_features='auto',
#                                        max_leaf_nodes=None, max_samples=None,
#                                        min_impurity_decrease=0.0,
#                                        min_impurity_split=None,
#                                        min_samples_leaf=1, min_samples_split=2,
#                                        min_weight_fraction_leaf=0.0,
#                                        n_estimators=100, n_jobs=None,
#                                        oob_score=False, random_state=14,
#                                        verbose=0, warm_start=False),
#       min_features_to_select=15, n_jobs=None, scoring='accuracy', step=1,
#       verbose=0)

# %%
support_list = list(rfecv.support_)

# %%
importance = []
for val, sup in list(zip(X.columns,support_list)):
    if sup == True:
        importance.append(val)

# %%
print(X[importance].shape)
X[importance].head()
# Out:
# (87396, 15)
#    lead_time  arrival_date_year  arrival_date_week_number  \
# 0        342               2015                        27
# 1        737               2015                        27
# 2          7               2015                        27
# 3         13               2015                        27
# 4         14               2015                        27
#
#    stays_in_week_nights   country  market_segment  previous_cancellations  \
# 0                     0  0.647913        0.852846                       0
# 1                     0  0.647913        0.852846                       0
# 2                     1  0.809738        0.852846                       0
# 3                     1  0.809738        0.878917                       0
# 4                     2  0.809738        0.646538                       0
#
#    deposit_type       agent  customer_type   adr  required_car_parking_spaces  \
# ...

# %%
x_and_y = pd.concat([X[importance],y],axis=1)

# %%
x_and_y = x_and_y[(np.abs(stats.zscore(x_and_y)) <= 3).all(axis=1)]
print(x_and_y.shape)
x_and_y.head()
# Out:
# (73245, 16)
#     lead_time  arrival_date_year  arrival_date_week_number  \
# 4          14               2015                        27
# 6           0               2015                        27
# 7           9               2015                        27
# 11         35               2015                        27
# 12         68               2015                        27
#
#     stays_in_week_nights   country  market_segment  previous_cancellations  \
# 4                      2  0.809738        0.646538                       0
# 6                      2  0.647913        0.852846                       0
# 7                      2  0.647913        0.852846                       0
# 11                     4  0.647913        0.646538                       0
# 12                     4  0.755200        0.646538                       0
#
#     deposit_type       agent  customer_type    adr  \
# 4       0.733151  240.000000       0.698941   98.0
# ...

# %%
X = x_and_y.drop('Target',axis=1)
y = x_and_y.Target

# %%
scaler = MinMaxScaler()
for col in X.columns:
    if (X[col]>=1).sum() > 0:
        X[col] = scaler.fit_transform(X[[col]])

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,random_state=seed,test_size=0.3)

# %%
y_train.value_counts()
# Out:
# 0    36752
# 1    14519
# Name: Target, dtype: int64

# %%
X_train, y_train = make_imbalance(X_train, y_train, sampling_strategy = {0:14000,1:14000})

# %%
y_train.value_counts()
# Out:
# 1    14000
# 0    14000
# Name: Target, dtype: int64

# %%
XGB = XGBClassifier(colsample_bytree=0.3, gamma=0.4, max_depth=9, min_child_weight=3, n_estimators=28)
XGB.fit(X_train, y_train)
Y_pred = XGB.predict(X_train)
acc_XGB = round(XGB.score(X_train, y_train) * 100, 2)
r_XGB = round(recall_score(y_train,Y_pred) * 100, 2)
p_XGB = round(precision_score(y_train,Y_pred) * 100, 2)
f_XGB = round(f1_score(y_train,Y_pred) * 100, 2)
print(f'accuracy: {acc_XGB},recall: {r_XGB}, precision: {p_XGB},f1: {f_XGB}')
print('')
fpr, tpr, threshold = roc_curve(y_train, Y_pred)
print(f'AUC: {round(auc(fpr,tpr),3)*100}')
print('')
plt.tight_layout()
plt.figure(figsize=(7,4))
(sns.heatmap(confusion_matrix(y_train, Y_pred),cmap="YlGnBu"))
# Out:
# accuracy: 99.41,recall: 99.41, precision: 99.42,f1: 99.41
#
# AUC: 99.4

# %%
XGB = XGBClassifier(colsample_bytree=0.3, gamma=0.4, max_depth=9, min_child_weight=3, n_estimators=28)
XGB.fit(X_train, y_train)
Y_pred = XGB.predict(X_test)
acc_XGB = round(XGB.score(X_test, y_test) * 100, 2)
r_XGB = round(recall_score(y_test,Y_pred) * 100, 2)
p_XGB = round(precision_score(y_test,Y_pred) * 100, 2)
f_XGB = round(f1_score(y_test,Y_pred) * 100, 2)
print(f'accuracy: {acc_XGB},recall: {r_XGB}, precision: {p_XGB},f1: {f_XGB}')
print('')
fpr, tpr, threshold = roc_curve(y_test, Y_pred)
print(f'AUC: {round(auc(fpr,tpr),3)*100}')
print('')
plt.tight_layout()
plt.figure(figsize=(7,4))
(sns.heatmap(confusion_matrix(y_test, Y_pred),cmap="YlGnBu"))
# Out:
# accuracy: 99.11,recall: 98.84, precision: 98.03,f1: 98.43
#
# AUC: 99.0

# %%
from sklearn.metrics import roc_curve, auc

rf_fpr, rf_tpr, tresh = roc_curve(y_test,Y_pred)
auc_rf = auc(rf_fpr,rf_tpr)

plt.figure(figsize=(8,5))
plt.plot(rf_fpr, rf_tpr, marker='.', label='RF (auc = %0.3f)' % auc_rf)

plt.xlabel('False Positive Rate -->')
plt.ylabel('True Positive Rate -->')

plt.legend()

plt.show()

# %%
from xgboost import plot_importance
plt.tight_layout()
plt.figure(figsize=(15,8))
plot_importance(XGB)
plt.show()

# %%
rf = RandomForestClassifier()
rf.fit(X_train,y_train)
pred = rf.predict(X_test)
score = rf.score(X_test,y_test)

# %%
a = pd.DataFrame(rf.feature_importances_).T
a.columns = X.columns

# %%
importance_of_features = a.T.sort_values(by=0,ascending=False)
importance_of_features
# Out:
#                                     0
# reservation_status           0.820579
# reservation_status_date      0.030925
# market_segment               0.030181
# lead_time                    0.030067
# country                      0.023881
# agent                        0.015236
# total_of_special_requests    0.013323
# adr                          0.010375
# customer_type                0.007068
# arrival_date_week_number     0.005955
# arrival_date_year            0.005514
# stays_in_week_nights         0.003598
# previous_cancellations       0.003262
# deposit_type                 0.000035
# required_car_parking_spaces  0.000000

# %%
## this code is designed to find the number of features needed in the X data for an optimal accuracy score

def optimize_score_rfe(dataframe,method,style,target_variable,cross_val=5,goal='accuracy'):
    
    """
    Input a goal, method, style (the method of analysis written as a string), and number of cross validations and 
    receive an optimal score, number of features used, and list of features used as an output
    """
    
    from sklearn.preprocessing import MinMaxScaler
    from sklearn.feature_selection import RFE
    mms = MinMaxScaler()
    old_score = 0
    old_features_used = 1

    for i in range(1,df.shape[1]):
        y = dataframe.Target
        X = dataframe.drop('Target',axis=1)
        selector = RFE(method,n_features_to_select=i)
        # selector = RFECV(estimator=method, step=1, cv=StratifiedKFold(cross_val), scoring=goal,min_features_to_select=i)
        selector = selector.fit(X, y.values.ravel())
        selected_columns = X.columns[selector.support_]
        new_y = dataframe.Target
        new_X = dataframe[selected_columns]
        for col in new_X.columns:
            new_X[col] = mms.fit_transform(new_X[[col]])
        X_train, X_test, y_train, y_test = train_test_split(new_X,new_y,test_size=0.25,random_state=14) 
        method.fit(X_train,y_train)
        Y_pred = method.predict(X_test)
        if style == 'Linear_Regression':
            accuracy = r2_score(y_test, Y_pred)
        else:
            accuracy = accuracy_score(y_test, Y_pred)
        new_score = accuracy
        if new_score > old_score:
            score = new_score
            features_used = i
            old_score = new_score
            old_features_used = i
        else:
            score = old_score
            features_used = old_features_used
        # selector_new = RFECV(estimator=method, step=1, cv=StratifiedKFold(cross_val), scoring='accuracy',min_features_to_select=features_used)
        selector_new = RFE(method,n_features_to_select=features_used)
        selector_new = selector_new.fit(X, y.values.ravel())
        selected_columns_new = X.columns[selector_new.support_]

    print(f'Predicting: {target_variable}')
    print('')
    print(f'The optimal score is {100*round(score,2)}%, and it makes use of {features_used} features from the data.')
    print('')
    print(f'Those features are: {list(selected_columns_new)}')

# %%
optimize_score_rfe(df,XGBClassifier(),'XGB','Hotel Cancelations')
